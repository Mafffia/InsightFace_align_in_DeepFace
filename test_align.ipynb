# %%
from insightface.utils import face_align
import cv2
from insightface.app import FaceAnalysis
import face_align
import matplotlib.pyplot as plt
from deepface import DeepFace
from deepface.commons import functions
import CompareAlign

# %%
#img = './lfw_funneled/Henning_Scherf/Henning_Scherf_0001.jpg'
img = 'Ziwang_Xu_0001.jpg'
arc,deep = CompareAlign.compare(img)
# Out:
# ...
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00,  9.36it/s]

# %%
arc
# Out:
# {'age': 38,
#  'region': {'x': 0, 'y': 0, 'w': 112, 'h': 112},
#  'gender': 'Man',
#  'race': {'asian': 96.56169414520264,
#   'indian': 0.8773015812039375,
#   'black': 0.38214733358472586,
#   'white': 0.08332321885973215,
#   'middle eastern': 0.0033314161555608734,
#   'latino hispanic': 2.0922010764479637},
#  'dominant_race': 'asian',
#  'emotion': {'angry': 0.030944545869715512,
#   'disgust': 0.010530048166401684,
#   'fear': 0.05723194335587323,
#   'happy': 71.85596823692322,
#   'sad': 1.1701940558850765,
#   'surprise': 0.010026974632637575,
#   'neutral': 26.865103840827942},
#  'dominant_emotion': 'happy'}

# %%
deep
# Out:
# {'age': 39,
#  'region': {'x': 64, 'y': 67, 'w': 131, 'h': 131},
#  'gender': 'Man',
#  'race': {'asian': 88.79927396774292,
#   'indian': 4.299362748861313,
#   'black': 1.56476479023695,
#   'white': 0.25192168541252613,
#   'middle eastern': 0.01875153393484652,
#   'latino hispanic': 5.065933242440224},
#  'dominant_race': 'asian',
#  'emotion': {'angry': 0.18425238085910678,
#   'disgust': 3.0187371180545597e-05,
#   'fear': 0.12132271658629179,
#   'happy': 34.61574614048004,
#   'sad': 0.024391707847826183,
#   'surprise': 62.64748573303223,
#   'neutral': 2.4067748337984085},
#  'dominant_emotion': 'surprise'}

# %%
plt.imshow(cv2.cvtColor(cv2.imread(img), cv2.COLOR_BGR2RGB)  )

# %%
img = 'Quincy_Jones_0001.jpg'
arc,deep = CompareAlign.compare(img)
# Out:
# ...
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00, 10.04it/s]

# %%
arc
# Out:
# {'age': 33,
#  'region': {'x': 0, 'y': 0, 'w': 112, 'h': 112},
#  'gender': 'Man',
#  'race': {'asian': 0.004924640597891994,
#   'indian': 0.010024866787716746,
#   'black': 99.92395639419556,
#   'white': 6.301168014033465e-05,
#   'middle eastern': 8.183746302847794e-06,
#   'latino hispanic': 0.06102126790210605},
#  'dominant_race': 'black',
#  'emotion': {'angry': 3.8330791940140245,
#   'disgust': 1.1609639289686683e-09,
#   'fear': 0.0009578663255294736,
#   'happy': 4.411339467971214e-05,
#   'sad': 0.7069747385069572,
#   'surprise': 3.860408317045809e-10,
#   'neutral': 95.45894238108053},
#  'dominant_emotion': 'neutral'}

# %%
deep
# Out:
# {'age': 45,
#  'region': {'x': 68, 'y': 63, 'w': 126, 'h': 126},
#  'gender': 'Man',
#  'race': {'asian': 0.9559021539571468,
#   'indian': 1.2888584891090975,
#   'black': 94.79776558849402,
#   'white': 0.04844453646885293,
#   'middle eastern': 0.03642346562091597,
#   'latino hispanic': 2.872605964256044},
#  'dominant_race': 'black',
#  'emotion': {'angry': 0.47575936694499055,
#   'disgust': 6.691398945204147e-07,
#   'fear': 0.0007026374042180077,
#   'happy': 83.5364093504196,
#   'sad': 0.26772685082118813,
#   'surprise': 0.20531344985595046,
#   'neutral': 15.514087111597485},
#  'dominant_emotion': 'happy'}
