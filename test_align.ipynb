# %%
from insightface.utils import face_align
import cv2
from insightface.app import FaceAnalysis
import arcface_align
import matplotlib.pyplot as plt
from deepface import DeepFace
from deepface.commons import functions
# Out:
# 2021-11-29 00:31:13.893897: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/mafffia/anaconda3/envs/torch/lib/python3.9/site-packages/cv2/../../lib64:
# 2021-11-29 00:31:13.893916: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
img = './lfw_funneled/Henning_Scherf/Henning_Scherf_0001.jpg'

face_img = arcface_align.get_face_align(img)
# Out:
# 2021-11-29 00:31:14.932262: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-29 00:31:14.932718: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/mafffia/anaconda3/envs/torch/lib/python3.9/site-packages/cv2/../../lib64:
# 2021-11-29 00:31:14.932784: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/mafffia/anaconda3/envs/torch/lib/python3.9/site-packages/cv2/../../lib64:
# ...

# %%
plt.imshow(face_img)

# %%
obj = DeepFace.analyze(img_path = face_img, actions = ['age', 'gender', 'race', 'emotion'],detector_backend='skip',align=False)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00,  6.61it/s]

# %%
obj
# Out:
# {'age': 41,
#  'region': {'x': 0, 'y': 0, 'w': 112, 'h': 112},
#  'gender': 'Man',
#  'race': {'asian': 0.2273499927476057,
#   'indian': 0.016190103886338604,
#   'black': 0.0005383418551341096,
#   'white': 96.32794304753028,
#   'middle eastern': 1.829945264167158,
#   'latino hispanic': 1.5980288343991238},
#  'dominant_race': 'white',
#  'emotion': {'angry': 0.0003415559807619618,
#   'disgust': 1.2581660552815906e-05,
#   'fear': 0.00012393399685801197,
#   'happy': 99.11554450485376,
#   'sad': 0.09308876442506996,
#   'surprise': 7.781743713607608e-07,
#   'neutral': 0.7908897014492572},
#  'dominant_emotion': 'happy'}

# %%
obj = DeepFace.analyze(img_path = './lfw_funneled/Henning_Scherf/Henning_Scherf_0001.jpg', actions = ['age', 'gender', 'race', 'emotion'],detector_backend='opencv',align=True)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:00<00:00,  8.82it/s]

# %%
obj
# Out:
# {'age': 45,
#  'region': {'x': 75, 'y': 68, 'w': 113, 'h': 113},
#  'gender': 'Man',
#  'race': {'asian': 30.83343207836151,
#   'indian': 11.880990117788315,
#   'black': 7.62801393866539,
#   'white': 15.378667414188385,
#   'middle eastern': 12.841333448886871,
#   'latino hispanic': 21.437568962574005},
#  'dominant_race': 'asian',
#  'emotion': {'angry': 0.12535621644929051,
#   'disgust': 0.0011556170647963881,
#   'fear': 2.409381978213787,
#   'happy': 56.58082365989685,
#   'sad': 1.376076228916645,
#   'surprise': 0.020976521773263812,
#   'neutral': 39.48623538017273},
#  'dominant_emotion': 'happy'}

# %%
len(rep)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_338592/1301124795.py in <module>
# ----> 1 len(rep)
#
# NameError: name 'rep' is not defined
